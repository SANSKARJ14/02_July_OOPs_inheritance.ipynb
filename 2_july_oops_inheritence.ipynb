# %% [markdown]
# 1. Explain what inheritance is in object-oriented programming and why it is used.
#
# inheritance is a fundamental concept that allows one class (called the subclass or derived class) to inherit the properties
# and behaviors of another class (called the superclass or base class).
# This means that a subclass can reuse and extend the characteristics and functionality of a superclass, forming a hierarchical
# relationship between classes.
#
# why it used
#
# A)Reuse of Code: Inheritance promotes code reusability by allowing you to define common attributes and methods in a base class.
#
# B)Abstraction and Modularity: Inheritance helps in creating abstract classes that define a common interface for a group
# of related classes.
#
# C)Polymorphism: it  allows objects of different classes to be treated as objects of a common base class, enabling more flexible
# and generic programming.
#
# d)Extensibility: Subclasses can add new attributes and methods or override the inherited ones to specialize the behavior
# of the base class. This enables you to adapt and extend existing code to accommodate specific requirements.

# %% [markdown]
# 2. Discuss the concept of single inheritance and multiple inheritance, highlighting their
# differences and advantages.
#
# Single Inheritance:
#
# Definition: In Single Inheritance, a subclass can inherit from only one superclass. This means that a class
# can have one direct parent class from which it inherits attributes and behaviors.
#
# Advantages:
#
# Simplicity: Single Inheritance tends to be simpler and easier to understand since there is a clear and
# linear hierarchy of classes.
#
# Avoids Diamond Problem: It eliminates the "diamond problem," a potential issue that can arise in Multiple Inheritance
# (explained below), where ambiguity occurs when a class inherits from two classes with a common ancestor.
#
# Multiple Inheritance:
#
# Definition: In Multiple Inheritance, a subclass can inherit from more than one superclass.
# This means that a class can have multiple parent classes from which it inherits attributes and behaviors.
#
# Advantages:
#
# Code Reuse: Multiple Inheritance allows for more extensive code reuse, as a class can inherit from multiple sources,
# potentially reducing redundancy and promoting modularity.
#
# Modeling Complex Relationships: It is useful for modeling complex relationships in the real world, where an object
# can possess attributes and behaviors from multiple sources.
#
# Differences:
#
# Number of Superclasses: The key difference is the number of superclasses a subclass can inherit from: one in Single Inheritance
# and multiple in Multiple Inheritance.
#
# Complexity: Single Inheritance is often considered simpler and less error-prone, making it a good choice for straightforward
# hierarchies. Multiple Inheritance can become more complex and may require careful design to avoid ambiguities.
#
# Diamond Problem: Multiple Inheritance can lead to the "diamond problem" when two or more superclasses have a common ancestor.
# This can result in ambiguity in method resolution, which must be addressed through various techniques,
# such as method precedence rules.

# %% [markdown]
# 3. Explain the terms "base class" and "derived class" in the context of inheritance.
#
#
# Base Class:
#
# -Also known as the "superclass" or "parent class."
# -The base class is the class from which one or more other classes inherit properties and behaviors.
# -It serves as the template or blueprint for the derived classes.
# -The base class defines common attributes and methods that are shared by its derived classes.
# -The primary purpose of a base class is to provide a foundation for code reuse and to establish a common interface for its
# derived classes.
#
# Derived Class:
#
# -Also known as the "subclass" or "child class."
# -The derived class is a class that inherits attributes and behaviors from a base class.
# -It extends or specializes the functionality of the base class by adding its own attributes or methods, or by overriding
# inherited methods.
# -Derived classes can have their unique characteristics while benefiting from the common functionality defined in the base class.
# -The relationship between a derived class and its base class is often depicted as an "is-a" relationship,
# where the derived class "is a" specialized version of the base class.

# %% [markdown]
# 4. What is the significance of the "protected" access modifier in inheritance? How does
# it differ from "private" and "public" modifiers?
#
# The "protected" access modifier in inheritance allows class members (attributes and methods) to be accessible within the class
# where they are defined and in its subclasses (derived classes). It encourages controlled access to these members and supports
# the sharing of attributes and behaviors between base and derived classes, promoting code reusability and data integrity.
# While Python does not strictly enforce protection, the double underscore prefix (e.g., __protected_var) serves as a convention,
# signaling that these members should be treated as protected and not accessed directly from outside the class hierarchy.
#
#
# "Public" Access Modifier:
#
# Members marked as "public" are accessible from anywhere, both within the class and from external code.
# This means that they can be freely accessed and modified by any code that uses the class.
#
# Private" Access Modifier:
#
# Members marked as "private" are intended to be accessible only within the class itself.
# They are denoted by adding an underscore prefix, like _private_var.
# While Python doesn't enforce true encapsulation, this naming convention is a convention that suggests to other programmers
# that the variable should not be accessed directly from outside the class.
#
# "Protected" Access Modifier:
#
# Members marked as "protected" are intended to be accessible within the class and its subclasses (derived classes).
# They are denoted by adding a double underscore prefix, like __protected_var.
# In Python, it doesn't enforce strict protection, but it suggests that the variable should be treated as protected and
# not accessed directly from outside the class or its subclasses.

# %% [raw]
# 5. What is the purpose of the "super" keyword in inheritance? Provide an example.
#
# The "super" keyword in inheritance serves the purpose of calling a method or accessing attributes from the superclass
# (base class) within the context of a subclass (derived class). It allows you to invoke the superclass's
# implementation of a method or access its attributes while customizing or extending behavior in the subclass.
# This is particularly useful when you want to augment or override a method while still utilizing the functionality provided by
# the superclass.
#
# Here's an example in Python:
#
# class Animal:
#     def __init__(self, name):
#         self.name = name
#
#     def speak(self):
#         print(f"{self.name} makes a sound")
#
# class Dog(Animal):
#     def speak(self):
#         super().speak()  # Call the speak method from the superclass
#         print(f"{self.name} barks")
#
# my_dog = Dog("Buddy")
# my_dog.speak()

# %% [raw]
# 6. Create a base class called "Vehicle" with attributes like "make", "model", and "year".
# Then, create a derived class called "Car" that inherits from "Vehicle" and adds an
# attribute called "fuel_type". Implement appropriate methods in both classes.

# %%
class vehicle:
    def __init__(self,make,model,year):
        self.model = model 
        self.year = year 
        self.make = make 
        
    def display_info(self):
        print(f"Make: {self.make}")
        print(f"Model: {self.model}")
        print(f"Year: {self.year}")
        
class car(vehicle):
    def __init__(self,make,model,year,fuel_type):
        super().__init__(make,model,year)
        self.fuel_type = fuel_type
        
    def display_info(self):
        super().display_info()
        print(f"Fuel Type: {self.fuel_type}")
       
my_car = car("Toyota", "Camry", 2023, "Gasoline")
my_car.display_info()
# Out:
# Make: Toyota
# Model: Camry
# Year: 2023
# Fuel Type: Gasoline

# %% [raw]
# 7. Create a base class called "Employee" with attributes like "name" and "salary."
# Derive two classes, "Manager" and "Developer," from "Employee." Add an additional
# attribute called "department" for the "Manager" class and "programming_language"
# for the "Developer" class.

# %%
class employee:
    def __init__(self,name,salary):
        self.name = name 
        self.salary = salary
        
    def display_info(self):
        print(f"Name: {self.name}")
        print(f"salry:RS{self.salary}.2F")
              
class manager(employee):
    def __init__(self,name,salary,department):
        super().__init__(name,salary)
        self.department = department
        
    def display_info(self):
        super().display_info()
        print(f"department is :{self.department}")
            
              
class developer(employee):
    def __init__(self,name,salary,programming_class):
        super().__init__(name,salary)
        self.programming_class = programming_class
        
    def display_info(self):
        super().display_info()
        print(f"programming class is :{self.programming_class}")
        
              
manager = manager("Alice", 80000, "Human Resources")
developer = developer("Bob", 75000, "Python")

print("Manager Information:")
manager.display_info()

print("\nDeveloper Information:")
developer.display_info()
# Out:
# Manager Information:
# Name: Alice
# salry:RS80000.2F
# department is :Human Resources
#
# Developer Information:
# Name: Bob
# salry:RS75000.2F
# programming class is :Python

# %% [raw]
# 8. Design a base class called "Shape" with attributes like "colour" and "border_width."
# Create derived classes, "Rectangle" and "Circle," that inherit from "Shape" and add
# specific attributes like "length" and "width" for the "Rectangle" class and "radius" for
# the "Circle" class.

# %%
class Shape:
    def __init__(self, color, border_width):
        self.color = color
        self.border_width = border_width

    def display_info(self):
        print(f"Color: {self.color}")
        print(f"Border Width: {self.border_width}")


class Rectangle(Shape):
    def __init__(self, color, border_width, length, width):
        super().__init__(color, border_width)
        self.length = length
        self.width = width

    def display_info(self):
        super().display_info()
        print(f"Shape: Rectangle")
        print(f"Length: {self.length}")
        print(f"Width: {self.width}")


class Circle(Shape):
    def __init__(self, color, border_width, radius):
        super().__init__(color, border_width)
        self.radius = radius

    def display_info(self):
        super().display_info()
        print(f"Shape: Circle")
        print(f"Radius: {self.radius}")


# Example usage:
rectangle = Rectangle("Blue", 2, 10, 5)
circle = Circle("Red", 1, 7)

print("Rectangle Information:")
rectangle.display_info()

print("\nCircle Information:")
circle.display_info()
# Out:
# Rectangle Information:
# Color: Blue
# Border Width: 2
# Shape: Rectangle
# Length: 10
# Width: 5
#
# Circle Information:
# Color: Red
# Border Width: 1
# Shape: Circle
# Radius: 7

# %% [raw]
# 9. Create a base class called "Device" with attributes like "brand" and "model." Derive
# two classes, "Phone" and "Tablet," from "Device." Add specific attributes like
# "screen_size" for the "Phone" class and "battery_capacity" for the "Tablet" class.

# %%
class Device:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        print(f"Brand: {self.brand}")
        print(f"Model: {self.model}")


class Phone(Device):
    def __init__(self, brand, model, screen_size):
        super().__init__(brand, model)
        self.screen_size = screen_size

    def display_info(self):
        super().display_info()
        print(f"Type: Phone")
        print(f"Screen Size: {self.screen_size} inches")


class Tablet(Device):
    def __init__(self, brand, model, battery_capacity):
        super().__init__(brand, model)
        self.battery_capacity = battery_capacity

    def display_info(self):
        super().display_info()
        print(f"Type: Tablet")
        print(f"Battery Capacity: {self.battery_capacity} mAh")


# Example usage:
iphone = Phone("Apple", "iPhone 13", 6.1)
ipad = Tablet("Apple", "iPad Pro", 10000)

print("Phone Information:")
iphone.display_info()

print("\nTablet Information:")
ipad.display_info()
# Out:
# Phone Information:
# Brand: Apple
# Model: iPhone 13
# Type: Phone
# Screen Size: 6.1 inches
#
# Tablet Information:
# Brand: Apple
# Model: iPad Pro
# Type: Tablet
# Battery Capacity: 10000 mAh

# %% [raw]
# 10. Create a base class called "BankAccount" with attributes like "account_number" and
# "balance." Derive two classes, "SavingsAccount" and "CheckingAccount," from
# "BankAccount." Add specific methods like "calculate_interest" for the
# "SavingsAccount" class and "deduct_fees" for the "CheckingAccount" class.

# %%
class BankAccount:
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance

    def display_info(self):
        print(f"Account Number: {self.account_number}")
        print(f"Balance: ${self.balance:.2f}")


class SavingsAccount(BankAccount):
    def __init__(self, account_number, balance, interest_rate):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def calculate_interest(self):
        interest = self.balance * (self.interest_rate / 100)
        self.balance += interest
        print(f"Interest Earned: ${interest:.2f}")
        print(f"Updated Balance: ${self.balance:.2f}")


class CheckingAccount(BankAccount):
    def __init__(self, account_number, balance, monthly_fee):
        super().__init__(account_number, balance)
        self.monthly_fee = monthly_fee

    def deduct_fees(self):
        if self.balance >= self.monthly_fee:
            self.balance -= self.monthly_fee
            print(f"Monthly Fee Deducted: ${self.monthly_fee:.2f}")
            print(f"Updated Balance: ${self.balance:.2f}")
        else:
            print("Insufficient balance to deduct monthly fee.")


# Example usage:
savings_account = SavingsAccount("SAV123", 5000, 2.5)
checking_account = CheckingAccount("CHK456", 3000, 10)

print("Savings Account Information:")
savings_account.display_info()
savings_account.calculate_interest()

print("\nChecking Account Information:")
checking_account.display_info()
checking_account.deduct_fees()
# Out:
# Savings Account Information:
# Account Number: SAV123
# Balance: $5000.00
# Interest Earned: $125.00
# Updated Balance: $5125.00
#
# Checking Account Information:
# Account Number: CHK456
# Balance: $3000.00
# Monthly Fee Deducted: $10.00
# Updated Balance: $2990.00
